# %%
import pandas as  pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Nicer looking plots
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)

# %%
df = pd.read_csv('../data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
print("Shape:", df.shape)
# Out:
# Shape: (7043, 21)

# %%
print("\nData Types:\n", df.dtypes)
# Out:
# Data Types:
#  customerID              str
# gender                  str
# SeniorCitizen         int64
# Partner                 str
# Dependents              str
# tenure                int64
# PhoneService            str
# MultipleLines           str
# InternetService         str
# OnlineSecurity          str
# OnlineBackup            str
# DeviceProtection        str
# TechSupport             str
# StreamingTV             str
# StreamingMovies         str
# Contract                str
# PaperlessBilling        str
# PaymentMethod           str
# MonthlyCharges      float64
# TotalCharges            str
# Churn                   str
# dtype: object

# %%
print("\nMissing values:\n", df.isnull().sum())
# Out:
# Missing values:
#  customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# Churn Rate 
print(df['Churn'].value_counts())
print("\nChurn Rate (%):\n", df['Churn'].value_counts(normalize=True) * 100)
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64
#
# Churn Rate (%):
#  Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
# Check for hidden spaces/empty strings

print(df[df['TotalCharges'].str.strip() == ''])
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
# Convert TotalCharges to numeric, empty strings become NaN
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# Check how many NaN values we now have
print("Missing TotalCharges after conversion:", df['TotalCharges'].isnull().sum())

# Since these are all tenure=0 customers, fill with 0 (makes logical sense)
df['TotalCharges'] = df['TotalCharges'].fillna(0)

# Confirm fix
print("Missing TotalCharges after fix:", df['TotalCharges'].isnull().sum())
print("\nNew dtype:", df['TotalCharges'].dtype)
# Out:
# Missing TotalCharges after conversion: 11
# Missing TotalCharges after fix: 0
#
# New dtype: float64

# %%
#Churn Rate
print(df['Churn'].value_counts())
print("\nChurn Rate (%):\n", df['Churn'].value_counts(normalize=True) * 100)
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64
#
# Churn Rate (%):
#  Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
#Churn Distribution Graph
print("Churn Distribution Graph")
plt.figure(figsize=(6,5))
sns.countplot(data=df, x='Churn', palette=['#2ecc71', '#e74c3c'])
plt.title('Customer Churn Distribution')
plt.xlabel('Churn')
plt.ylabel('Number of Customers')
plt.show()
# Out:
# Churn Distribution Graph
# C:\Users\MY PC\AppData\Local\Temp\ipykernel_9128\4289739107.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Churn', palette=['#2ecc71', '#e74c3c'])

# %%
#Churn by Contract Type
print("Churn by Contract Type")

plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Contract', hue='Churn', palette=['#2ecc71', '#e74c3c'])
plt.title('Churn by Contract Type')
plt.xlabel('Contract Type')
plt.ylabel('Number of Customers')
plt.show()
# Out:
# Churn by Contract Type
